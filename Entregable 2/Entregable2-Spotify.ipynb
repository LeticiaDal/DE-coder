# %% [markdown]
# ## Para este ejercicio uso la API de Spotify y extraigo los new releases de albums en Argentina y Uruguay para ampliar la cantidad de registros y también poder realizar algunas transformaciones de datos. La idea es generar un dataset con los 50 nuevos lanzamientos de Argentina y Uruguay, tener informacion del Artista, Album, Fecha de lanzamiento, canciones del album y cantidad de veces que fueron reproducidas cada una. Con esta información puedo saber por ejemplo que albumes son los mas escuchados y los menos escuchados para tomar alguna acción de marketing sobre eso.
#
# Para ello uso la api de Spotify https://spotipy.readthedocs.io/en/2.22.1/

# %%
# !pip install spotipy --upgrade
# !pip install -U datasets
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: spotipy in /opt/conda/lib/python3.10/site-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in /opt/conda/lib/python3.10/site-packages (from spotipy) (4.5.5)
# Requirement already satisfied: requests>=2.25.0 in /opt/conda/lib/python3.10/site-packages (from spotipy) (2.28.2)
# Requirement already satisfied: six>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from spotipy) (1.26.15)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/conda/lib/python3.10/site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (11.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.0.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.28.2)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.15.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (23.1)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.10/site-packages (2.9.6)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import os
import psycopg2

from pyspark.sql import SparkSession
from pyspark.sql.functions import when, lit, col

# %%
env = os.environ

# %% [markdown]
# Creo un cliente para conectar a Spotify

# %%
# Configurar las credenciales de cliente de Spotify
client_id = env['SPOTIFY_CLIENT_ID']
client_secret = env['SPOTIFY_CLIENT_SECRET']

# Crear una instancia de SpotifyClientCredentials con las credenciales
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# Crear una instancia de la clase Spotipy
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# Recupero los datos que necesito de Spotify y creo una lista para guardarlos

# %%
# Obtener los últimos lanzamientos en Argentina
results_ar = sp.new_releases(country='AR', limit=50)
albums_ar = results_ar['albums']['items']

# Obtener los últimos lanzamientos en Uruguay
results_uy = sp.new_releases(country='UY', limit=50)
albums_uy = results_uy['albums']['items']

# Combinar los resultados de Argentina y Uruguay
all_albums = albums_ar + albums_uy

# Crear una lista para almacenar los datos
data = []

for album in all_albums:
    artist_name = album['artists'][0]['name']
    album_name = album['name']
    release_date = album['release_date']
    album_id = album['id']
     
    # Obtener las canciones del álbum
    tracks = sp.album_tracks(album_id)
    
    for i, track in enumerate(tracks['items']):
        track_name = track['name']
        
        # Obtener las estadísticas de reproducción de la canción
        track_stats = sp.track(track['id'])
        num_playbacks = track_stats['popularity']
        
        data.append((artist_name , album_name , release_date, track_name, num_playbacks))

data
# Out:
# [('Bizarrap',
#   'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#   '2023-06-01',
#   'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#   93),
#  ('LIT killah', 'Los del Espacio', '2023-06-01', 'Los del Espacio', 85),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'El Amor Después del Amor - EADDA9223',
#   59),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Dos Días en la Vida - EADDA9223 (feat. Lali & Nicki Nicole)',
#   64),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'La Verónica - EADDA9223 (feat. NATHY PELUSO)',
#   58),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Tráfico por Katmandú - EADDA9223 (feat. Elvis Costello)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Pétalo de Sal - EADDA9223 (feat. Chico Buarque)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Sasha, Sissi y el Círculo de Baba - EADDA9223 (feat. Mon Laferte)',
#   59),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Un Vestido y un Amor - EADDA9223 (feat. Marisa Monte)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Tumbas de la Gloria - EADDA9223 (feat. María Castillo de Lima)',
#   56),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'La Rueda Mágica - EADDA9223 (feat. Andrés Calamaro & Conociendo Rusia)',
#   58),
#  ('Fito Paez', 'EADDA9223', '2023-05-30', 'Creo - EADDA9223', 55),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Detrás del Muro de los Lamentos - EADDA9223 (feat. Antonio Carmona & Estrella Morente)',
#   54),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'La Balada de Donna Helena - EADDA9223 (feat. WOS & CA7RIEL)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Brillante Sobre el Mic - EADDA9223',
#   55),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'A Rodar Mi Vida - EADDA9223 (feat. David Lebón & Leiva)',
#   55),
#  ('C.R.O', 'Temor', '2023-06-01', 'Abismo', 55),
#  ('C.R.O', 'Temor', '2023-06-01', 'Una Opción', 54),
#  ('C.R.O', 'Temor', '2023-06-01', 'Silencio', 54),
#  ('C.R.O', 'Temor', '2023-06-01', 'Temor', 63),
#  ('C.R.O', 'Temor', '2023-06-01', 'Yendo Hacia Tí', 56),
#  ('C.R.O', 'Temor', '2023-06-01', 'Encontrándote', 56),
#  ('C.R.O', 'Temor', '2023-06-01', 'Dame Rock', 57),
#  ('C.R.O', 'Temor', '2023-06-01', 'A Tu Manera', 58),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Nuevo Comienzo', 49),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'VOID', 49),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Las Flores Sangran', 48),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Salto al Espacio', 48),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'TRAS', 50),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Melodía del Viento', 47),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Sol', 46),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Nena, dime algo.', 48),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Cabo', 47),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Horizonte', 46),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'La Verdad', 46),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Calma', 45),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Gandalf', 43),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Madame Razzmatazz - En directo Razzmatazz',
#   37),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Salud, dinero & amor - En directo Razzmatazz',
#   38),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Carnaval de Brasil - En directo Razzmatazz',
#   40),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Más duele - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'El día de la mujer mundial - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'All You Need Is Pop - En directo Razzmatazz',
#   35),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Por mirarte - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'La mirada del adiós - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Mil horas - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Cada una de tus cosas - En directo Razzmatazz',
#   35),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Para seguir - En directo Razzmatazz',
#   34),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Nunca es igual + Get Up Stand Up - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'MVP Blues - En directo Razzmatazz',
#   32),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Ansia en Plaza Francia - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Revolución turra - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'El perro - En directo Razzmatazz',
#   32),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Los divinos - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Me envenenaste - En directo Razzmatazz',
#   44),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Voy a dormir / Socio de la soledad - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Mi enfermedad - En directo Razzmatazz',
#   34),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Palabras más, palabras menos - En directo Razzmatazz',
#   32),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Jumping Jack Flash - En directo Razzmatazz',
#   31),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'El salmón - En directo Razzmatazz',
#   33),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Eloping', 33),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Milanesa al Pan', 35),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Nube Negra', 33),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Amor, Amor', 32),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Modus Operandi', 32),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Bolero', 30),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Mensaje Codificado', 30),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Millionaire', 36),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Wandering Rebel', 30),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Carriage', 29),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Let Loose', 28),
#  ('Juan Wauters',
#   'Wandering Rebel',
#   '2023-06-02',
#   'En un barrio de Montevideo',
#   28),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'REMEMBER', 16),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'LATINAS', 17),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'TINDER uwu', 15),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'AMOR INTRO', 17),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'AMOR', 18),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'NIÑA', 16),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'BESO', 14),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'ELLA (CAE LA NOCHE)', 26),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'CIELO', 16),
#  ('Bocho', 'DIAMANTE', '2023-06-01', '10/10', 13),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'ABRE', 13),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Rescued', 71),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Under You', 70),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Hearing Voices', 70),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'But Here We Are', 69),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'The Glass', 72),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Nothing At All', 69),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Show Me How', 68),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Beyond Me', 67),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'The Teacher', 67),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Rest', 66),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Hablar de ti - En Vivo Baires',
#   26),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Témpera - En Vivo Baires',
#   25),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Bienvenida Buenos Aires (Palabras) - En Vivo Baires',
#   24),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Pepitas - En Vivo Baires',
#   23),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Carta a Cuba (Palabras) - En Vivo Baires',
#   22),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Nueva Canción de la Trova - En Vivo Baires',
#   22),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Caminante, Pt. 1 (Poema) - En Vivo Baires',
#   21),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Los Colores - En Vivo Baires',
#   22),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El pez nuestro de cada día (Palabras) - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Barcos de Cristal - En Vivo Baires',
#   21),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Caminanta Kuki (Palabras) - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Amor (Canto para una semilla) - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Canción del Desvelado - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Ni perdón ni olvido (Palabras) - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Luchín - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La lluvia en Buenos Aires (Poema) - En Vivo Baires',
#   18),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Un Rey y un Diez - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Sobre todo, los muertos (Palabras) - En Vivo Baires',
#   0),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Los Dinosaurios - En Vivo Baires',
#   33),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Aguja - En Vivo Baires',
#   18),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Medusa - En Vivo Baires',
#   18),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Caminante, Pt. 2 (Poema) - En Vivo Baires',
#   16),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Danza de las Libélulas - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Agradecimientos (Palabras) - En Vivo Baires',
#   16),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Viejo Comunista - En Vivo Baires',
#   18),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'Ya No', 64),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'DISPARA ***', 78),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', "NO voy a llorar :')", 65),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', '8 AM', 75),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'Se va 1 llegan 2', 66),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'Llámame', 65),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'qué le pasa conmigo?', 73),
#  ('Nicki Nicole',
#   'ALMA',
#   '2023-05-18',
#   'Tuyo (Cover) - una que quise hacer',
#   63),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'CAEN LAS ESTRELLAS', 74),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'TIENES MI ALMA', 63),
#  ('Lali', 'LALI', '2023-04-13', 'Obsesión', 71),
#  ('Lali', 'LALI', '2023-04-13', 'Disciplina', 59),
#  ('Lali', 'LALI', '2023-04-13', 'Cómprame un Brishito', 57),
#  ('Lali', 'LALI', '2023-04-13', 'KO', 59),
#  ('Lali', 'LALI', '2023-04-13', '2 Son 3', 58),
#  ('Lali', 'LALI', '2023-04-13', 'Incondicional', 58),
#  ('Lali', 'LALI', '2023-04-13', 'Quiénes Son?', 64),
#  ('Lali', 'LALI', '2023-04-13', 'Diva', 57),
#  ('Lali', 'LALI', '2023-04-13', 'N5', 59),
#  ('Lali', 'LALI', '2023-04-13', 'Ahora', 57),
#  ('Lali', 'LALI', '2023-04-13', 'MOTIVEISHON', 56),
#  ('Lali', 'LALI', '2023-04-13', 'Como Tú', 55),
#  ('Lali', 'LALI', '2023-04-13', 'Sola', 59),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Jefa', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Nena Trampa', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Isla Velde', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Yo Yo y Yo', 43),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Piensame', 43),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Peli-Culeo', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Fulete', 41),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'La Trampa', 42),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Maléfica', 43),
#  ('Cazzu',
#   'Nena Trampa (Deluxe Edition)',
#   '2023-04-13',
#   'Los Hombres No Lloran',
#   42),
#  ('Cazzu',
#   'Nena Trampa (Deluxe Edition)',
#   '2023-04-13',
#   'Peli-Culeo - Remix',
#   52),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Brinca', 74),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Glock', 68),
#  ('Cazzu',
#   'Nena Trampa (Deluxe Edition)',
#   '2023-04-13',
#   'Piénsame - Mariachi',
#   49),
#  ('Cazzu',
#   'Nena Trampa (Deluxe Edition)',
#   '2023-04-13',
#   'Los Hombres No Lloran - Orquesta',
#   43),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'AN1MAL', 55),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'DISCOTEKA', 61),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'LA SANTA', 62),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'TURISMO', 57),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'SLOWMOTION', 54),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'CORAZONES ROTOS', 61),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'PARA OLVIDARME DE TI', 53),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'LAS SOLTERAS', 53),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'ULTRAVIOLETA', 61),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'EL TONTO', 84),
#  ('Lola Indigo', 'EL DRAGÓN', '2023-04-13', 'DRAGÓN', 59),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Alma Mater', 24),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Gps', 23),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Rayos X', 25),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Modo Avión', 25),
#  ('Connie Isla',
#   'Isla Mater',
#   '2023-04-13',
#   'Laberinto (feat. Leo Rizzi)',
#   27),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Nubes', 23),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Viaje', 22),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Cometa Ti', 24),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Fugaz', 42),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Andromeda', 21),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Luna En Venus', 21),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Materia', 21),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'Pangea', 20),
#  ('Connie Isla', 'Isla Mater', '2023-04-13', 'No Ves', 19),
#  ('Milo j', '511', '2023-04-13', 'FLA', 74),
#  ('Milo j', '511', '2023-04-13', 'NO MUCHO', 69),
#  ('Milo j', '511', '2023-04-13', 'AL BORDE', 81),
#  ('Milo j', '511', '2023-04-13', '511 (INTERLUDIO)', 15),
#  ('Milo j', '511', '2023-04-13', 'TOI HECHO', 70),
#  ('Bhavi', 'ABDUCCION', '2023-04-10', 'FANTASTICO', 41),
#  ('Bhavi', 'ABDUCCION', '2023-04-10', 'GASTO', 40),
#  ('Bhavi', 'ABDUCCION', '2023-04-10', 'CLARO QUE SI', 39),
#  ('Bhavi', 'ABDUCCION', '2023-04-10', 'SABBOT', 38),
#  ('Bhavi', 'ABDUCCION', '2023-04-10', 'AEROBICO', 46),
#  ('Bhavi', 'ABDUCCION', '2023-04-10', 'OMG', 39),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Río causal', 25),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Caramelo roto', 24),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Música bailando', 27),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Algo', 26),
#  ('Anyi',
#   'Luz de perla',
#   '2023-04-14',
#   'Esos que se aman se están por odiar',
#   22),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Soy un volcán', 37),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Máscara de miel', 23),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Chau te voy a extrañar', 20),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Pista viva', 25),
#  ('Anyi', 'Luz de perla', '2023-04-14', 'Pido 1 deseo', 27),
#  ('Anyi',
#   'Luz de perla',
#   '2023-04-14',
#   'Entre el cielo y la tierra estoy yo',
#   22),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'A.K', 28),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'ARABIE', 32),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'FRAMA', 23),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'FUMANDO MENOS', 28),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'CALLEJERA', 26),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'ÚLTIMAMENTE', 26),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'MA MONEY', 23),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'ME OYES', 45),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'RED FLAG', 23),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'TIEMPO', 25),
#  ('Delfina Dib', 'Directo al Cora', '2023-04-14', 'YORY NO', 39),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Padre Tiempo', 73),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Gladiador - Remix', 68),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'El Hokage', 76),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Mbappé - Remix', 70),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Si Salimos', 74),
#  ('Eladio Carrion',
#   '3MEN2 KBRN',
#   '2023-03-17',
#   '¿Qué Carajos Quieres Tú Ahora?',
#   74),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Cuevita', 69),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Coco Chanel', 92),
#  ('Eladio Carrion',
#   '3MEN2 KBRN',
#   '2023-03-17',
#   'Si La Calle Llama - Remix',
#   86),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Peso a Peso', 70),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Mala Mía Otra Vez', 69),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Friends - Remix', 71),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Quizás, Tal Vez', 72),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'M3', 66),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Betty', 71),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Haciendo Dinero', 66),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', '¿Como? (Skit)', 59),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Air France', 65),
#  ('Manuel Turizo', '2000', '2023-03-17', 'No Te Sientes Igual', 53),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Triste', 63),
#  ('Manuel Turizo', '2000', '2023-03-17', 'El Merengue', 57),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Jamaica', 66),
#  ('Manuel Turizo', '2000', '2023-03-17', 'U Lala', 55),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Verte de Nuevo', 61),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Guayabo', 62),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Inténtalo', 50),
#  ('Manuel Turizo', '2000', '2023-03-17', 'La Bachata', 87),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Vacío', 51),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Despecho', 55),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Éxtasis', 66),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Te Olvido', 57),
#  ('Manuel Turizo', '2000', '2023-03-17', 'De 100 a 0', 50),
#  ('Manuel Turizo',
#   '2000',
#   '2023-03-17',
#   'De 100 a 0 - Arles & Dann Remix',
#   45),
#  ('Los Bunkers', 'Rey', '2023-03-11', 'Rey', 52),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Impulso', 37),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Laberinto', 44),
#  ('Adrián Berra',
#   'Respirar Bajo el Agua',
#   '2023-03-15',
#   'Lluvia en el salón',
#   41),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Patria', 33),
#  ('Adrián Berra',
#   'Respirar Bajo el Agua',
#   '2023-03-15',
#   'Antenas en la ciudad',
#   32),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Caminata', 36),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Oración', 30),
#  ('U2', 'Songs Of Surrender', '2023-03-17', 'One - Songs Of Surrender', 53),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Where The Streets Have No Name - Songs Of Surrender',
#   52),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Stories For Boys - Songs Of Surrender',
#   52),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "11 O'Clock Tick Tock - Songs Of Surrender",
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Out Of Control - Songs Of Surrender',
#   51),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Beautiful Day - Songs Of Surrender',
#   53),
#  ('U2', 'Songs Of Surrender', '2023-03-17', 'Bad - Songs Of Surrender', 52),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Every Breaking Wave - Songs Of Surrender',
#   51),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Walk On (Ukraine) - Songs Of Surrender',
#   49),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Pride (In The Name Of Love) - Songs Of Surrender',
#   51),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "Who's Gonna Ride Your Wild Horses - Songs Of Surrender",
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Get Out Of Your Own Way - Songs Of Surrender',
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "Stuck In A Moment You Can't Get Out Of - Songs Of Surrender",
#   49),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Red Hill Mining Town - Songs Of Surrender',
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Ordinary Love - Songs Of Surrender',
#   49),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "Sometimes You Can't Make It On Your Own - Songs Of Surrender",
#   47),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Invisible - Songs Of Surrender',
#   56),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Dirty Day - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'The Miracle (Of Joey Ramone) - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'City Of Blinding Lights - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Vertigo - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "I Still Haven't Found What I'm Looking For - Songs Of Surrender",
#   47),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Electrical Storm - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'The Fly - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'If God Will Send His Angels - Songs Of Surrender',
#   45),
#  ('U2', 'Songs Of Surrender', '2023-03-17', 'Desire - Songs Of Surrender', 45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Until The End Of The World - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Song For Someone - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'All I Want Is You - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Peace On Earth - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'With Or Without You - Songs Of Surrender',
#   47),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Stay (Faraway, So Close!) - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Sunday Bloody Sunday - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Lights Of Home - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Cedarwood Road - Songs Of Surrender',
#   42),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'I Will Follow - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Two Hearts Beat As One - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Miracle Drug - Songs Of Surrender',
#   42),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'The Little Things That Give You Away - Songs Of Surrender',
#   43),
#  ('U2', 'Songs Of Surrender', '2023-03-17', '"40" - Songs Of Surrender', 44),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Harakiri',
#   38),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Entrar a la luna',
#   30),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Corazón negro',
#   19),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Ya no manda',
#   19),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Adiós',
#   21),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Toda esa bronca',
#   18),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Mantarraya Reina',
#   19),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Húyanle a las culebras',
#   18),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Beatrix kiddo',
#   16),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'La santa patrona de los corazones negros',
#   17),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Flowers', 91),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Jaded', 84),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Rose Colored Lenses',
#   77),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Thousand Miles (feat. Brandi Carlile)',
#   75),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'You', 73),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Handstand', 68),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'River', 82),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Violet Chemistry',
#   71),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Muddy Feet (feat. Sia)',
#   73),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Wildcard', 70),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Island', 73),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Wonder Woman', 69),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Flowers (Demo)',
#   66),
#  ('Nicki Nicole',
#   "NO voy a llorar :')",
#   '2023-03-09',
#   "NO voy a llorar :')",
#   71),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Intro', 0),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Todo x Nada', 26),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Gatitas y Ratones', 31),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Sentimientos Encontrados', 45),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Decímelo de Una', 32),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Malas Decisiones', 38),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Cuál?', 27),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Ese Ser', 24),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Alto Trip', 23),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Ahí Voy', 26),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Voy Dejando Atrás', 24),
#  ('Los Ángeles Azules', 'Tú Y Tú', '2023-03-10', 'Tú Y Tú', 66),
#  ('King Savagge', 'WorKING', '2023-03-09', 'WorKING', 39),
#  ('King Savagge', 'WorKING', '2023-03-09', 'Tengo polola nueva', 47),
#  ('King Savagge', 'WorKING', '2023-03-09', 'NOPALATELE', 54),
#  ('King Savagge', 'WorKING', '2023-03-09', 'Fluye', 57),
#  ('King Savagge', 'WorKING', '2023-03-09', 'Lonely', 57),
#  ('King Savagge', 'WorKING', '2023-03-09', 'PFQG', 51),
#  ('King Savagge', 'WorKING', '2023-03-09', 'EO EO', 42),
#  ('King Savagge', 'WorKING', '2023-03-09', '2 Hielos', 71),
#  ('Princesa Alba', 'Búscate Otra :(', '2023-03-10', 'Búscate Otra :(', 49),
#  ('Lali', 'Cómprame un Brishito', '2023-03-01', 'Cómprame un Brishito', 51),
#  ('El Mató a un Policía Motorizado',
#   'Medalla de Oro',
#   '2023-03-03',
#   'Medalla de Oro',
#   23),
#  ('KAROL G',
#   'MAÑANA SERÁ BONITO',
#   '2023-02-24',
#   'MIENTRAS ME CURO DEL CORA',
#   90),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'X SI VOLVEMOS', 85),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'PERO TÚ', 82),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'BESTIES', 78),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'GUCCI LOS PAÑOS', 80),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'TQG', 96),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'TUS GAFITAS', 81),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'OJOS FERRARI', 77),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'MERCURIO', 74),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'GATÚBELA', 79),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'KÁRMIKA', 79),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'PROVENZA', 85),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'CAROLINA', 78),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'DAÑAMOS LA AMISTAD', 74),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'AMARGURA', 89),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'CAIRO', 83),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'MAÑANA SERÁ BONITO', 81),
#  ('TINI', 'Cupido', '2023-02-16', 'Cupido', 84),
#  ('TINI', 'Cupido', '2023-02-16', 'Te Pido', 70),
#  ('TINI', 'Cupido', '2023-02-16', 'Muñecas', 77),
#  ('TINI', 'Cupido', '2023-02-16', 'El Último Beso', 66),
#  ('TINI', 'Cupido', '2023-02-16', 'Carne y Hueso', 64),
#  ('TINI', 'Cupido', '2023-02-16', 'La Loto', 67),
#  ('TINI', 'Cupido', '2023-02-16', 'Las Jordans', 71),
#  ('TINI', 'Cupido', '2023-02-16', 'Beso En Las Rocas', 64),
#  ('TINI', 'Cupido', '2023-02-16', '7 Veces', 60),
#  ('TINI', 'Cupido', '2023-02-16', 'Fantasi', 66),
#  ('TINI', 'Cupido', '2023-02-16', 'Miénteme', 76),
#  ('TINI', 'Cupido', '2023-02-16', 'Maldita Foto', 61),
#  ('TINI', 'Cupido', '2023-02-16', 'Bar', 67),
#  ('TINI', 'Cupido', '2023-02-16', 'La Triple T', 75),
#  ('Duki',
#   'Si Me Sobrara el Tiempo',
#   '2023-02-16',
#   'Si Me Sobrara el Tiempo',
#   74),
#  ('Polimá Westcoast', 'TU ME QUIERES?', '2023-02-01', 'TU ME QUIERES?', 60),
#  ('KAROL G', 'X SI VOLVEMOS', '2023-02-03', 'X SI VOLVEMOS', 84),
#  ('Big One',
#   'En La Intimidad | CROSSOVER #1',
#   '2023-02-01',
#   'En La Intimidad | CROSSOVER #1',
#   85),
#  ('Maluma', 'La Fórmula', '2023-02-01', 'La Fórmula', 78),
#  ('Ñengo Flow', 'Gato de Noche', '2022-12-22', 'Gato de Noche', 88),
#  ('Zoe Gotusso',
#   'Spotify Singles',
#   '2022-12-22',
#   'Ganas - Spotify Singles',
#   45),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Diablo Santo', 50),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Bellakito', 56),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Mi Amiga (feat. Easykid)', 50),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Rica', 49),
#  ('DrefQuila',
#   'Diablo Santo',
#   '2022-12-15',
#   'Kela Toke (feat. Tunechikidd)',
#   56),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Salir A Buscarte', 49),
#  ('ROSALÍA', 'DESPECHÁ RMX', '2022-12-16', 'DESPECHÁ RMX', 70),
#  ('Cris Mj', 'Marisola (Remix)', '2022-12-15', 'Marisola - Remix', 86),
#  ('Harry Nach', 'LOKOTRON REMIX', '2022-12-16', 'LOKOTRON REMIX', 69),
#  ('Denise Rosenthal',
#   'Centenas De Miles De Años',
#   '2022-12-15',
#   'Centenas De Miles De Años',
#   45),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'Fe En Lo Que Yo Quiera',
#   35),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Korea', 35),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'Que Sigas Bien',
#   38),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'El Rey Ha Muerto',
#   31),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Rufián', 37),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'De Esos Días', 34),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Insuperable', 34),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Quise', 37),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Sirenas', 32),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Roma', 33),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'Yo Lloraré Con Vos',
#   31),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Un Rato Más', 35),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Todo Se Quema', 25),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Alimentacion.com', 21),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Soles Y Flores', 26),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'La Amistad', 23),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Las Ausencias', 24),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Dios Naturaleza', 26),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Estuche', 24),
#  ('León Gieco',
#   'El Hombrecito Del Mar',
#   '2022-12-16',
#   'Gira, Gira Girasol',
#   19),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Mis Heridas Cure', 36),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Por Hoy', 19),
#  ('León Gieco',
#   'El Hombrecito Del Mar',
#   '2022-12-16',
#   'Sueño Con Serpientes',
#   29),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'El Final', 18),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'El Orgullo', 21),
#  ('un muerto mas',
#   'Verano en Invierno',
#   '2022-12-16',
#   'Frutillas con Crema',
#   29),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Puente', 30),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Carita Triste', 23),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Amor de Verano', 37),
#  ('un muerto mas',
#   'Verano en Invierno',
#   '2022-12-16',
#   'Tu Perro, Tus Amigas',
#   23),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Liberen al Pity', 25),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Me Gustas Tanto', 22),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'La Isla del Sol', 39),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Tratamiento', 35),
#  ('un muerto mas',
#   'Verano en Invierno',
#   '2022-12-16',
#   'Desde Que Te Fuiste',
#   21),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Monstruo', 18),
#  ('Bizarrap',
#   'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#   '2023-06-01',
#   'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#   93),
#  ('LIT killah', 'Los del Espacio', '2023-06-01', 'Los del Espacio', 85),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'El Amor Después del Amor - EADDA9223',
#   59),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Dos Días en la Vida - EADDA9223 (feat. Lali & Nicki Nicole)',
#   64),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'La Verónica - EADDA9223 (feat. NATHY PELUSO)',
#   58),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Tráfico por Katmandú - EADDA9223 (feat. Elvis Costello)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Pétalo de Sal - EADDA9223 (feat. Chico Buarque)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Sasha, Sissi y el Círculo de Baba - EADDA9223 (feat. Mon Laferte)',
#   59),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Un Vestido y un Amor - EADDA9223 (feat. Marisa Monte)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Tumbas de la Gloria - EADDA9223 (feat. María Castillo de Lima)',
#   56),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'La Rueda Mágica - EADDA9223 (feat. Andrés Calamaro & Conociendo Rusia)',
#   58),
#  ('Fito Paez', 'EADDA9223', '2023-05-30', 'Creo - EADDA9223', 55),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Detrás del Muro de los Lamentos - EADDA9223 (feat. Antonio Carmona & Estrella Morente)',
#   54),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'La Balada de Donna Helena - EADDA9223 (feat. WOS & CA7RIEL)',
#   57),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'Brillante Sobre el Mic - EADDA9223',
#   55),
#  ('Fito Paez',
#   'EADDA9223',
#   '2023-05-30',
#   'A Rodar Mi Vida - EADDA9223 (feat. David Lebón & Leiva)',
#   55),
#  ('C.R.O', 'Temor', '2023-06-01', 'Abismo', 55),
#  ('C.R.O', 'Temor', '2023-06-01', 'Una Opción', 54),
#  ('C.R.O', 'Temor', '2023-06-01', 'Silencio', 54),
#  ('C.R.O', 'Temor', '2023-06-01', 'Temor', 63),
#  ('C.R.O', 'Temor', '2023-06-01', 'Yendo Hacia Tí', 56),
#  ('C.R.O', 'Temor', '2023-06-01', 'Encontrándote', 56),
#  ('C.R.O', 'Temor', '2023-06-01', 'Dame Rock', 57),
#  ('C.R.O', 'Temor', '2023-06-01', 'A Tu Manera', 58),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Nuevo Comienzo', 49),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'VOID', 49),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Las Flores Sangran', 48),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Salto al Espacio', 48),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'TRAS', 50),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Melodía del Viento', 47),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Sol', 46),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Nena, dime algo.', 48),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Cabo', 47),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Horizonte', 46),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'La Verdad', 46),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Calma', 45),
#  ('Usted Señalemelo', 'Tripolar', '2023-05-29', 'Gandalf', 43),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Madame Razzmatazz - En directo Razzmatazz',
#   37),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Salud, dinero & amor - En directo Razzmatazz',
#   38),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Carnaval de Brasil - En directo Razzmatazz',
#   40),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Más duele - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'El día de la mujer mundial - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'All You Need Is Pop - En directo Razzmatazz',
#   35),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Por mirarte - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'La mirada del adiós - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Mil horas - En directo Razzmatazz',
#   36),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Cada una de tus cosas - En directo Razzmatazz',
#   35),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Para seguir - En directo Razzmatazz',
#   34),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Nunca es igual + Get Up Stand Up - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'MVP Blues - En directo Razzmatazz',
#   32),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Ansia en Plaza Francia - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Revolución turra - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'El perro - En directo Razzmatazz',
#   32),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Los divinos - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Me envenenaste - En directo Razzmatazz',
#   44),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Voy a dormir / Socio de la soledad - En directo Razzmatazz',
#   33),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Mi enfermedad - En directo Razzmatazz',
#   34),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Palabras más, palabras menos - En directo Razzmatazz',
#   32),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'Jumping Jack Flash - En directo Razzmatazz',
#   31),
#  ('Andrés Calamaro',
#   'Razzmatazz (En directo Razzmatazz)',
#   '2023-06-02',
#   'El salmón - En directo Razzmatazz',
#   33),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Eloping', 33),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Milanesa al Pan', 35),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Nube Negra', 33),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Amor, Amor', 32),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Modus Operandi', 32),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Bolero', 30),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Mensaje Codificado', 30),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Millionaire', 36),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Wandering Rebel', 30),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Carriage', 29),
#  ('Juan Wauters', 'Wandering Rebel', '2023-06-02', 'Let Loose', 28),
#  ('Juan Wauters',
#   'Wandering Rebel',
#   '2023-06-02',
#   'En un barrio de Montevideo',
#   28),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'REMEMBER', 16),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'LATINAS', 17),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'TINDER uwu', 15),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'AMOR INTRO', 17),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'AMOR', 18),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'NIÑA', 16),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'BESO', 14),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'ELLA (CAE LA NOCHE)', 26),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'CIELO', 16),
#  ('Bocho', 'DIAMANTE', '2023-06-01', '10/10', 13),
#  ('Bocho', 'DIAMANTE', '2023-06-01', 'ABRE', 13),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Rescued', 71),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Under You', 70),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Hearing Voices', 70),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'But Here We Are', 69),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'The Glass', 72),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Nothing At All', 69),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Show Me How', 68),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Beyond Me', 67),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'The Teacher', 67),
#  ('Foo Fighters', 'But Here We Are', '2023-06-02', 'Rest', 66),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Hablar de ti - En Vivo Baires',
#   26),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Témpera - En Vivo Baires',
#   25),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Bienvenida Buenos Aires (Palabras) - En Vivo Baires',
#   24),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Pepitas - En Vivo Baires',
#   23),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Carta a Cuba (Palabras) - En Vivo Baires',
#   22),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Nueva Canción de la Trova - En Vivo Baires',
#   22),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Caminante, Pt. 1 (Poema) - En Vivo Baires',
#   21),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Los Colores - En Vivo Baires',
#   22),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El pez nuestro de cada día (Palabras) - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Barcos de Cristal - En Vivo Baires',
#   21),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Caminanta Kuki (Palabras) - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Amor (Canto para una semilla) - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Canción del Desvelado - En Vivo Baires',
#   20),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Ni perdón ni olvido (Palabras) - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Luchín - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La lluvia en Buenos Aires (Poema) - En Vivo Baires',
#   18),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Un Rey y un Diez - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Sobre todo, los muertos (Palabras) - En Vivo Baires',
#   0),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Los Dinosaurios - En Vivo Baires',
#   33),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Aguja - En Vivo Baires',
#   18),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Medusa - En Vivo Baires',
#   18),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Caminante, Pt. 2 (Poema) - En Vivo Baires',
#   16),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'La Danza de las Libélulas - En Vivo Baires',
#   19),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'Agradecimientos (Palabras) - En Vivo Baires',
#   16),
#  ('Manuel García',
#   'Manuel García en Buenos Aires (En Vivo)',
#   '2023-06-02',
#   'El Viejo Comunista - En Vivo Baires',
#   18),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'Ya No', 64),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'DISPARA ***', 78),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', "NO voy a llorar :')", 65),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', '8 AM', 75),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'Se va 1 llegan 2', 66),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'Llámame', 65),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'qué le pasa conmigo?', 73),
#  ('Nicki Nicole',
#   'ALMA',
#   '2023-05-18',
#   'Tuyo (Cover) - una que quise hacer',
#   63),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'CAEN LAS ESTRELLAS', 74),
#  ('Nicki Nicole', 'ALMA', '2023-05-18', 'TIENES MI ALMA', 63),
#  ('Lali', 'LALI', '2023-04-13', 'Obsesión', 71),
#  ('Lali', 'LALI', '2023-04-13', 'Disciplina', 59),
#  ('Lali', 'LALI', '2023-04-13', 'Cómprame un Brishito', 57),
#  ('Lali', 'LALI', '2023-04-13', 'KO', 59),
#  ('Lali', 'LALI', '2023-04-13', '2 Son 3', 58),
#  ('Lali', 'LALI', '2023-04-13', 'Incondicional', 58),
#  ('Lali', 'LALI', '2023-04-13', 'Quiénes Son?', 64),
#  ('Lali', 'LALI', '2023-04-13', 'Diva', 57),
#  ('Lali', 'LALI', '2023-04-13', 'N5', 59),
#  ('Lali', 'LALI', '2023-04-13', 'Ahora', 57),
#  ('Lali', 'LALI', '2023-04-13', 'MOTIVEISHON', 56),
#  ('Lali', 'LALI', '2023-04-13', 'Como Tú', 55),
#  ('Lali', 'LALI', '2023-04-13', 'Sola', 59),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Jefa', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Nena Trampa', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Isla Velde', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Yo Yo y Yo', 43),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Piensame', 43),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Peli-Culeo', 45),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Fulete', 41),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'La Trampa', 42),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Maléfica', 43),
#  ('Cazzu',
#   'Nena Trampa (Deluxe Edition)',
#   '2023-04-13',
#   'Los Hombres No Lloran',
#   42),
#  ('Cazzu',
#   'Nena Trampa (Deluxe Edition)',
#   '2023-04-13',
#   'Peli-Culeo - Remix',
#   52),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Brinca', 74),
#  ('Cazzu', 'Nena Trampa (Deluxe Edition)', '2023-04-13', 'Glock', 68),
#  ('Cazzu',
# ...
#  ('Eladio Carrion',
#   '3MEN2 KBRN',
#   '2023-03-17',
#   'Si La Calle Llama - Remix',
#   86),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Peso a Peso', 70),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Mala Mía Otra Vez', 69),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Friends - Remix', 71),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Quizás, Tal Vez', 72),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'M3', 66),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Betty', 71),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Haciendo Dinero', 66),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', '¿Como? (Skit)', 59),
#  ('Eladio Carrion', '3MEN2 KBRN', '2023-03-17', 'Air France', 65),
#  ('Manuel Turizo', '2000', '2023-03-17', 'No Te Sientes Igual', 53),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Triste', 63),
#  ('Manuel Turizo', '2000', '2023-03-17', 'El Merengue', 57),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Jamaica', 66),
#  ('Manuel Turizo', '2000', '2023-03-17', 'U Lala', 55),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Verte de Nuevo', 61),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Guayabo', 62),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Inténtalo', 50),
#  ('Manuel Turizo', '2000', '2023-03-17', 'La Bachata', 87),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Vacío', 51),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Despecho', 55),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Éxtasis', 66),
#  ('Manuel Turizo', '2000', '2023-03-17', 'Te Olvido', 57),
#  ('Manuel Turizo', '2000', '2023-03-17', 'De 100 a 0', 50),
#  ('Manuel Turizo',
#   '2000',
#   '2023-03-17',
#   'De 100 a 0 - Arles & Dann Remix',
#   45),
#  ('Los Bunkers', 'Rey', '2023-03-11', 'Rey', 52),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Impulso', 37),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Laberinto', 44),
#  ('Adrián Berra',
#   'Respirar Bajo el Agua',
#   '2023-03-15',
#   'Lluvia en el salón',
#   41),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Patria', 33),
#  ('Adrián Berra',
#   'Respirar Bajo el Agua',
#   '2023-03-15',
#   'Antenas en la ciudad',
#   32),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Caminata', 36),
#  ('Adrián Berra', 'Respirar Bajo el Agua', '2023-03-15', 'Oración', 30),
#  ('U2', 'Songs Of Surrender', '2023-03-17', 'One - Songs Of Surrender', 53),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Where The Streets Have No Name - Songs Of Surrender',
#   52),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Stories For Boys - Songs Of Surrender',
#   52),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "11 O'Clock Tick Tock - Songs Of Surrender",
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Out Of Control - Songs Of Surrender',
#   51),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Beautiful Day - Songs Of Surrender',
#   53),
#  ('U2', 'Songs Of Surrender', '2023-03-17', 'Bad - Songs Of Surrender', 52),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Every Breaking Wave - Songs Of Surrender',
#   51),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Walk On (Ukraine) - Songs Of Surrender',
#   49),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Pride (In The Name Of Love) - Songs Of Surrender',
#   51),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "Who's Gonna Ride Your Wild Horses - Songs Of Surrender",
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Get Out Of Your Own Way - Songs Of Surrender',
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "Stuck In A Moment You Can't Get Out Of - Songs Of Surrender",
#   49),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Red Hill Mining Town - Songs Of Surrender',
#   50),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Ordinary Love - Songs Of Surrender',
#   49),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "Sometimes You Can't Make It On Your Own - Songs Of Surrender",
#   47),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Invisible - Songs Of Surrender',
#   56),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Dirty Day - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'The Miracle (Of Joey Ramone) - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'City Of Blinding Lights - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Vertigo - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   "I Still Haven't Found What I'm Looking For - Songs Of Surrender",
#   47),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Electrical Storm - Songs Of Surrender',
#   46),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'The Fly - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'If God Will Send His Angels - Songs Of Surrender',
#   45),
#  ('U2', 'Songs Of Surrender', '2023-03-17', 'Desire - Songs Of Surrender', 45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Until The End Of The World - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Song For Someone - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'All I Want Is You - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Peace On Earth - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'With Or Without You - Songs Of Surrender',
#   47),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Stay (Faraway, So Close!) - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Sunday Bloody Sunday - Songs Of Surrender',
#   45),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Lights Of Home - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Cedarwood Road - Songs Of Surrender',
#   42),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'I Will Follow - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Two Hearts Beat As One - Songs Of Surrender',
#   43),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'Miracle Drug - Songs Of Surrender',
#   42),
#  ('U2',
#   'Songs Of Surrender',
#   '2023-03-17',
#   'The Little Things That Give You Away - Songs Of Surrender',
#   43),
#  ('U2', 'Songs Of Surrender', '2023-03-17', '"40" - Songs Of Surrender', 44),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Harakiri',
#   38),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Entrar a la luna',
#   30),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Corazón negro',
#   19),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Ya no manda',
#   19),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Adiós',
#   21),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Toda esa bronca',
#   18),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Mantarraya Reina',
#   19),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Húyanle a las culebras',
#   18),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'Beatrix kiddo',
#   16),
#  ('Mel Muñiz',
#   'La Santa Patrona de los Corazones Negros',
#   '2023-03-14',
#   'La santa patrona de los corazones negros',
#   17),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Flowers', 91),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Jaded', 84),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Rose Colored Lenses',
#   77),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Thousand Miles (feat. Brandi Carlile)',
#   75),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'You', 73),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Handstand', 68),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'River', 82),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Violet Chemistry',
#   71),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Muddy Feet (feat. Sia)',
#   73),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Wildcard', 70),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Island', 73),
#  ('Miley Cyrus', 'Endless Summer Vacation', '2023-03-10', 'Wonder Woman', 69),
#  ('Miley Cyrus',
#   'Endless Summer Vacation',
#   '2023-03-10',
#   'Flowers (Demo)',
#   66),
#  ('Nicki Nicole',
#   "NO voy a llorar :')",
#   '2023-03-09',
#   "NO voy a llorar :')",
#   71),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Intro', 0),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Todo x Nada', 26),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Gatitas y Ratones', 31),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Sentimientos Encontrados', 45),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Decímelo de Una', 32),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Malas Decisiones', 38),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Cuál?', 27),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Ese Ser', 24),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Alto Trip', 23),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Ahí Voy', 26),
#  ('Turf', 'Renacimiento', '2023-03-10', 'Voy Dejando Atrás', 24),
#  ('Los Ángeles Azules', 'Tú Y Tú', '2023-03-10', 'Tú Y Tú', 66),
#  ('King Savagge', 'WorKING', '2023-03-09', 'WorKING', 39),
#  ('King Savagge', 'WorKING', '2023-03-09', 'Tengo polola nueva', 47),
#  ('King Savagge', 'WorKING', '2023-03-09', 'NOPALATELE', 54),
#  ('King Savagge', 'WorKING', '2023-03-09', 'Fluye', 57),
#  ('King Savagge', 'WorKING', '2023-03-09', 'Lonely', 57),
#  ('King Savagge', 'WorKING', '2023-03-09', 'PFQG', 51),
#  ('King Savagge', 'WorKING', '2023-03-09', 'EO EO', 42),
#  ('King Savagge', 'WorKING', '2023-03-09', '2 Hielos', 71),
#  ('Princesa Alba', 'Búscate Otra :(', '2023-03-10', 'Búscate Otra :(', 49),
#  ('Lali', 'Cómprame un Brishito', '2023-03-01', 'Cómprame un Brishito', 51),
#  ('El Mató a un Policía Motorizado',
#   'Medalla de Oro',
#   '2023-03-03',
#   'Medalla de Oro',
#   23),
#  ('KAROL G',
#   'MAÑANA SERÁ BONITO',
#   '2023-02-24',
#   'MIENTRAS ME CURO DEL CORA',
#   90),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'X SI VOLVEMOS', 85),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'PERO TÚ', 82),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'BESTIES', 78),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'GUCCI LOS PAÑOS', 80),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'TQG', 96),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'TUS GAFITAS', 81),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'OJOS FERRARI', 77),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'MERCURIO', 74),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'GATÚBELA', 79),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'KÁRMIKA', 79),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'PROVENZA', 85),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'CAROLINA', 78),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'DAÑAMOS LA AMISTAD', 74),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'AMARGURA', 89),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'CAIRO', 83),
#  ('KAROL G', 'MAÑANA SERÁ BONITO', '2023-02-24', 'MAÑANA SERÁ BONITO', 81),
#  ('TINI', 'Cupido', '2023-02-16', 'Cupido', 84),
#  ('TINI', 'Cupido', '2023-02-16', 'Te Pido', 70),
#  ('TINI', 'Cupido', '2023-02-16', 'Muñecas', 77),
#  ('TINI', 'Cupido', '2023-02-16', 'El Último Beso', 66),
#  ('TINI', 'Cupido', '2023-02-16', 'Carne y Hueso', 64),
#  ('TINI', 'Cupido', '2023-02-16', 'La Loto', 67),
#  ('TINI', 'Cupido', '2023-02-16', 'Las Jordans', 71),
#  ('TINI', 'Cupido', '2023-02-16', 'Beso En Las Rocas', 64),
#  ('TINI', 'Cupido', '2023-02-16', '7 Veces', 60),
#  ('TINI', 'Cupido', '2023-02-16', 'Fantasi', 66),
#  ('TINI', 'Cupido', '2023-02-16', 'Miénteme', 76),
#  ('TINI', 'Cupido', '2023-02-16', 'Maldita Foto', 61),
#  ('TINI', 'Cupido', '2023-02-16', 'Bar', 67),
#  ('TINI', 'Cupido', '2023-02-16', 'La Triple T', 75),
#  ('Duki',
#   'Si Me Sobrara el Tiempo',
#   '2023-02-16',
#   'Si Me Sobrara el Tiempo',
#   74),
#  ('Polimá Westcoast', 'TU ME QUIERES?', '2023-02-01', 'TU ME QUIERES?', 60),
#  ('KAROL G', 'X SI VOLVEMOS', '2023-02-03', 'X SI VOLVEMOS', 84),
#  ('Big One',
#   'En La Intimidad | CROSSOVER #1',
#   '2023-02-01',
#   'En La Intimidad | CROSSOVER #1',
#   85),
#  ('Maluma', 'La Fórmula', '2023-02-01', 'La Fórmula', 78),
#  ('Ñengo Flow', 'Gato de Noche', '2022-12-22', 'Gato de Noche', 88),
#  ('Zoe Gotusso',
#   'Spotify Singles',
#   '2022-12-22',
#   'Ganas - Spotify Singles',
#   45),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Diablo Santo', 50),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Bellakito', 56),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Mi Amiga (feat. Easykid)', 50),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Rica', 49),
#  ('DrefQuila',
#   'Diablo Santo',
#   '2022-12-15',
#   'Kela Toke (feat. Tunechikidd)',
#   56),
#  ('DrefQuila', 'Diablo Santo', '2022-12-15', 'Salir A Buscarte', 49),
#  ('ROSALÍA', 'DESPECHÁ RMX', '2022-12-16', 'DESPECHÁ RMX', 70),
#  ('Cris Mj', 'Marisola (Remix)', '2022-12-15', 'Marisola - Remix', 86),
#  ('Harry Nach', 'LOKOTRON REMIX', '2022-12-16', 'LOKOTRON REMIX', 69),
#  ('Denise Rosenthal',
#   'Centenas De Miles De Años',
#   '2022-12-15',
#   'Centenas De Miles De Años',
#   45),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'Fe En Lo Que Yo Quiera',
#   35),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Korea', 35),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'Que Sigas Bien',
#   38),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'El Rey Ha Muerto',
#   31),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Rufián', 37),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'De Esos Días', 34),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Insuperable', 34),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Quise', 37),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Sirenas', 32),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Roma', 33),
#  ('EMI',
#   'Cada Segundo Dura Una Eternidad',
#   '2022-12-16',
#   'Yo Lloraré Con Vos',
#   31),
#  ('EMI', 'Cada Segundo Dura Una Eternidad', '2022-12-16', 'Un Rato Más', 35),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Todo Se Quema', 25),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Alimentacion.com', 21),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Soles Y Flores', 26),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'La Amistad', 23),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Las Ausencias', 24),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Dios Naturaleza', 26),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Estuche', 24),
#  ('León Gieco',
#   'El Hombrecito Del Mar',
#   '2022-12-16',
#   'Gira, Gira Girasol',
#   19),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Mis Heridas Cure', 36),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'Por Hoy', 19),
#  ('León Gieco',
#   'El Hombrecito Del Mar',
#   '2022-12-16',
#   'Sueño Con Serpientes',
#   29),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'El Final', 18),
#  ('León Gieco', 'El Hombrecito Del Mar', '2022-12-16', 'El Orgullo', 21),
#  ('un muerto mas',
#   'Verano en Invierno',
#   '2022-12-16',
#   'Frutillas con Crema',
#   29),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Puente', 30),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Carita Triste', 23),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Amor de Verano', 37),
#  ('un muerto mas',
#   'Verano en Invierno',
#   '2022-12-16',
#   'Tu Perro, Tus Amigas',
#   23),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Liberen al Pity', 25),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Me Gustas Tanto', 22),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'La Isla del Sol', 39),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Tratamiento', 35),
#  ('un muerto mas',
#   'Verano en Invierno',
#   '2022-12-16',
#   'Desde Que Te Fuiste',
#   21),
#  ('un muerto mas', 'Verano en Invierno', '2022-12-16', 'Monstruo', 18)]

# %%
# Postgres and Redshift JDBCs
driver_path = "/home/coder/working_dir/driver_jdbc/postgresql-42.2.27.jre7.jar"

os.environ['PYSPARK_SUBMIT_ARGS'] = f'--driver-class-path {driver_path} --jars {driver_path} pyspark-shell'
os.environ['SPARK_CLASSPATH'] = driver_path

# Create SparkSession 
spark = SparkSession.builder \
        .master("local") \
        .appName("Conexion entre Pyspark y Redshift") \
        .config("spark.jars", driver_path) \
        .config("spark.executor.extraClassPath", driver_path) \
        .getOrCreate()

# %% [markdown]
# Creación de un dataframe en spark con los datos obtenidos

# %%
# Creacion del DataFrame con los datos 
df = spark.createDataFrame(data, ['Artista','Album','Fecha_release','Track','Reprod_track'])
df.printSchema()
df.show()
# Out:
# root
#  |-- Artista: string (nullable = true)
#  |-- Album: string (nullable = true)
#  |-- Fecha_release: string (nullable = true)
#  |-- Track: string (nullable = true)
#  |-- Reprod_track: long (nullable = true)
#
# +----------+--------------------+-------------+--------------------+------------+
# |   Artista|               Album|Fecha_release|               Track|Reprod_track|
# +----------+--------------------+-------------+--------------------+------------+
# |  Bizarrap|Peso Pluma: Bzrp ...|   2023-06-01|Peso Pluma: Bzrp ...|          93|
# |LIT killah|     Los del Espacio|   2023-06-01|     Los del Espacio|          85|
# | Fito Paez|           EADDA9223|   2023-05-30|El Amor Después d...|          59|
# | Fito Paez|           EADDA9223|   2023-05-30|Dos Días en la Vi...|          64|
# | Fito Paez|           EADDA9223|   2023-05-30|La Verónica - EAD...|          58|
# | Fito Paez|           EADDA9223|   2023-05-30|Tráfico por Katma...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Pétalo de Sal - E...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Sasha, Sissi y el...|          59|
# | Fito Paez|           EADDA9223|   2023-05-30|Un Vestido y un A...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Tumbas de la Glor...|          56|
# | Fito Paez|           EADDA9223|   2023-05-30|La Rueda Mágica -...|          58|
# | Fito Paez|           EADDA9223|   2023-05-30|    Creo - EADDA9223|          55|
# | Fito Paez|           EADDA9223|   2023-05-30|Detrás del Muro d...|          54|
# | Fito Paez|           EADDA9223|   2023-05-30|La Balada de Donn...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Brillante Sobre e...|          55|
# | Fito Paez|           EADDA9223|   2023-05-30|A Rodar Mi Vida -...|          55|
# |     C.R.O|               Temor|   2023-06-01|              Abismo|          55|
# |     C.R.O|               Temor|   2023-06-01|          Una Opción|          54|
# |     C.R.O|               Temor|   2023-06-01|            Silencio|          54|
# |     C.R.O|               Temor|   2023-06-01|               Temor|          63|
# +----------+--------------------+-------------+--------------------+------------+
# only showing top 20 rows

# %% [markdown]
# ETAPA DE TRANSFORMACION - Suma de cantidad de reproducciones por canción, eliminacion de nulls, eliminacion de duplicados, transformacion de fecha tipo string a fecha tipo date, suma de cantidad de reproducciones en total del album (contando las reproducciones de cada cancion)

# %%
# eliminacion de nulls en cualquier columna
print ('cant registros dataframe',df_final.count())
df_final=df.na.drop(how="any")
print ('cant registros dataframe sin nulls',df_final.count())
df_final.show()
# Out:
# cant registros dataframe 852
# cant registros dataframe sin nulls 852
# +----------+--------------------+-------------+--------------------+------------+
# |   Artista|               Album|Fecha_release|               Track|Reprod_track|
# +----------+--------------------+-------------+--------------------+------------+
# |  Bizarrap|Peso Pluma: Bzrp ...|   2023-06-01|Peso Pluma: Bzrp ...|          93|
# |LIT killah|     Los del Espacio|   2023-06-01|     Los del Espacio|          85|
# | Fito Paez|           EADDA9223|   2023-05-30|El Amor Después d...|          59|
# | Fito Paez|           EADDA9223|   2023-05-30|Dos Días en la Vi...|          64|
# | Fito Paez|           EADDA9223|   2023-05-30|La Verónica - EAD...|          58|
# | Fito Paez|           EADDA9223|   2023-05-30|Tráfico por Katma...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Pétalo de Sal - E...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Sasha, Sissi y el...|          59|
# | Fito Paez|           EADDA9223|   2023-05-30|Un Vestido y un A...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Tumbas de la Glor...|          56|
# | Fito Paez|           EADDA9223|   2023-05-30|La Rueda Mágica -...|          58|
# | Fito Paez|           EADDA9223|   2023-05-30|    Creo - EADDA9223|          55|
# | Fito Paez|           EADDA9223|   2023-05-30|Detrás del Muro d...|          54|
# | Fito Paez|           EADDA9223|   2023-05-30|La Balada de Donn...|          57|
# | Fito Paez|           EADDA9223|   2023-05-30|Brillante Sobre e...|          55|
# | Fito Paez|           EADDA9223|   2023-05-30|A Rodar Mi Vida -...|          55|
# |     C.R.O|               Temor|   2023-06-01|              Abismo|          55|
# |     C.R.O|               Temor|   2023-06-01|          Una Opción|          54|
# |     C.R.O|               Temor|   2023-06-01|            Silencio|          54|
# |     C.R.O|               Temor|   2023-06-01|               Temor|          63|
# +----------+--------------------+-------------+--------------------+------------+
# only showing top 20 rows

# %%
# suma la cantidad de reproducciones por cancion
print ('cant registros dataframe',df_final.count())
df_final = spark.sql("select Artista, Album, Track, Fecha_release, sum(Cant_reprod_track) as Cant_reprod_track from temp group by Artista, Album, Track, Fecha_release")
print ('cant registros luego de sumar',df_final.count())
df_final.show()
# Out:
# cant registros dataframe 852
# cant registros luego de sumar 426
# +----------------+--------------------+--------------------+-------------+-----------------+
# |         Artista|               Album|               Track|Fecha_release|Cant_reprod_track|
# +----------------+--------------------+--------------------+-------------+-----------------+
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               84|
# |     Connie Isla|          Isla Mater|                 Gps|   2023-04-13|               46|
# |     Connie Isla|          Isla Mater|              No Ves|   2023-04-13|               38|
# |     Delfina Dib|     Directo al Cora|             ME OYES|   2023-04-14|               90|
# |       Mel Muñiz|La Santa Patrona ...|     Toda esa bronca|   2023-03-14|               36|
# |      Ñengo Flow|       Gato de Noche|       Gato de Noche|   2022-12-22|              176|
# |    Foo Fighters|     But Here We Are|           Beyond Me|   2023-06-02|              134|
# |           Bhavi|           ABDUCCION|            AEROBICO|   2023-04-10|               92|
# |              U2|  Songs Of Surrender|Out Of Control - ...|   2023-03-17|              102|
# |              U2|  Songs Of Surrender|Invisible - Songs...|   2023-03-17|              112|
# |     Miley Cyrus|Endless Summer Va...|              Island|   2023-03-10|              146|
# |   un muerto mas|  Verano en Invierno|     La Isla del Sol|   2022-12-16|               78|
# |            Lali|                LALI|                  KO|   2023-04-13|              118|
# |     Delfina Dib|     Directo al Cora|                 A.K|   2023-04-14|               56|
# |            TINI|              Cupido|             Fantasi|   2023-02-16|              132|
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               86|
# |Usted Señalemelo|            Tripolar|           La Verdad|   2023-05-29|               92|
# |  Eladio Carrion|          3MEN2 KBRN|¿Qué Carajos Quie...|   2023-03-17|              148|
# |            TINI|              Cupido|             Te Pido|   2023-02-16|              140|
# | Andrés Calamaro|Razzmatazz (En di...|Me envenenaste - ...|   2023-06-02|               88|
# +----------------+--------------------+--------------------+-------------+-----------------+
# only showing top 20 rows

# %%
# eliminacion de duplicados (aunque en el anterior paso vemos que ya se eliminan los duplicados)
print ('cant registros antes de borrar duplicados',df_final.count())
df_final=df_final.distinct()
print ('cant registros luego de borrar duplicados',df_final.count())
# Out:
# cant registros antes de borrar duplicados 426
# cant registros luego de borrar duplicados 426

# %%
from pyspark.sql.functions import col, to_date

# cast del tipo string a date en la columna fecha_release
df_final = df_final.withColumn("Fecha_release", to_date(col("Fecha_release"), "yyyy-MM-dd"))
df_final.printSchema()
df_final.show()
# Out:
# root
#  |-- Artista: string (nullable = true)
#  |-- Album: string (nullable = true)
#  |-- Track: string (nullable = true)
#  |-- Fecha_release: date (nullable = true)
#  |-- Cant_reprod_track: long (nullable = true)
#
# +----------------+--------------------+--------------------+-------------+-----------------+
# |         Artista|               Album|               Track|Fecha_release|Cant_reprod_track|
# +----------------+--------------------+--------------------+-------------+-----------------+
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               84|
# |     Connie Isla|          Isla Mater|                 Gps|   2023-04-13|               46|
# |     Connie Isla|          Isla Mater|              No Ves|   2023-04-13|               38|
# |     Delfina Dib|     Directo al Cora|             ME OYES|   2023-04-14|               90|
# |       Mel Muñiz|La Santa Patrona ...|     Toda esa bronca|   2023-03-14|               36|
# |      Ñengo Flow|       Gato de Noche|       Gato de Noche|   2022-12-22|              176|
# |    Foo Fighters|     But Here We Are|           Beyond Me|   2023-06-02|              134|
# |           Bhavi|           ABDUCCION|            AEROBICO|   2023-04-10|               92|
# |              U2|  Songs Of Surrender|Out Of Control - ...|   2023-03-17|              102|
# |              U2|  Songs Of Surrender|Invisible - Songs...|   2023-03-17|              112|
# |     Miley Cyrus|Endless Summer Va...|              Island|   2023-03-10|              146|
# |   un muerto mas|  Verano en Invierno|     La Isla del Sol|   2022-12-16|               78|
# |            Lali|                LALI|                  KO|   2023-04-13|              118|
# |     Delfina Dib|     Directo al Cora|                 A.K|   2023-04-14|               56|
# |            TINI|              Cupido|             Fantasi|   2023-02-16|              132|
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               86|
# |Usted Señalemelo|            Tripolar|           La Verdad|   2023-05-29|               92|
# |  Eladio Carrion|          3MEN2 KBRN|¿Qué Carajos Quie...|   2023-03-17|              148|
# |            TINI|              Cupido|             Te Pido|   2023-02-16|              140|
# | Andrés Calamaro|Razzmatazz (En di...|Me envenenaste - ...|   2023-06-02|               88|
# +----------------+--------------------+--------------------+-------------+-----------------+
# only showing top 20 rows

# %%
# castea del tipo long a integer para la columna cant_reprod_track 
df_final = df_final.withColumn("Cant_reprod_track",col("Cant_reprod_track").cast("int"))
df_final.printSchema()
df_final.show()
# Out:
# root
#  |-- Artista: string (nullable = true)
#  |-- Album: string (nullable = true)
#  |-- Track: string (nullable = true)
#  |-- Fecha_release: date (nullable = true)
#  |-- Cant_reprod_track: integer (nullable = true)
#
# +----------------+--------------------+--------------------+-------------+-----------------+
# |         Artista|               Album|               Track|Fecha_release|Cant_reprod_track|
# +----------------+--------------------+--------------------+-------------+-----------------+
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               84|
# |     Connie Isla|          Isla Mater|                 Gps|   2023-04-13|               46|
# |     Connie Isla|          Isla Mater|              No Ves|   2023-04-13|               38|
# |     Delfina Dib|     Directo al Cora|             ME OYES|   2023-04-14|               90|
# |       Mel Muñiz|La Santa Patrona ...|     Toda esa bronca|   2023-03-14|               36|
# |      Ñengo Flow|       Gato de Noche|       Gato de Noche|   2022-12-22|              176|
# |    Foo Fighters|     But Here We Are|           Beyond Me|   2023-06-02|              134|
# |           Bhavi|           ABDUCCION|            AEROBICO|   2023-04-10|               92|
# |              U2|  Songs Of Surrender|Out Of Control - ...|   2023-03-17|              102|
# |              U2|  Songs Of Surrender|Invisible - Songs...|   2023-03-17|              112|
# |     Miley Cyrus|Endless Summer Va...|              Island|   2023-03-10|              146|
# |   un muerto mas|  Verano en Invierno|     La Isla del Sol|   2022-12-16|               78|
# |            Lali|                LALI|                  KO|   2023-04-13|              118|
# |     Delfina Dib|     Directo al Cora|                 A.K|   2023-04-14|               56|
# |            TINI|              Cupido|             Fantasi|   2023-02-16|              132|
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               86|
# |Usted Señalemelo|            Tripolar|           La Verdad|   2023-05-29|               92|
# |  Eladio Carrion|          3MEN2 KBRN|¿Qué Carajos Quie...|   2023-03-17|              148|
# |            TINI|              Cupido|             Te Pido|   2023-02-16|              140|
# | Andrés Calamaro|Razzmatazz (En di...|Me envenenaste - ...|   2023-06-02|               88|
# +----------------+--------------------+--------------------+-------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ETAPA DE CARGA - Creación de tabla en Redshift y carga de datos del dataframe

# %%
connection = psycopg2.connect(
    host=env['AWS_REDSHIFT_HOST'],
    port=env['AWS_REDSHIFT_PORT'],
    dbname=env['AWS_REDSHIFT_DBNAME'],
    user=env['AWS_REDSHIFT_USER'],
    password=env['AWS_REDSHIFT_PASSWORD'],
)

# %%
# creacion de tabla en redshift  

cursor = connection.cursor()
cursor.execute(f"""
create table if not exists {env['AWS_REDSHIFT_SCHEMA']}.new_releases_aruy_spotify (
    artista VARCHAR(30) distkey,
    album VARCHAR(30),
    fecha_release DATE,
    track VARCHAR(30),
    cant_reprod_track INT
) sortkey(fecha_release);
""")
connection.commit()

cursor.close()
print("Table created!")
# Out:
# Table created!

# %%
#carga el dataframe en la tabla de redshift
df_final.write \
    .format("jdbc") \
    .option("url", f"jdbc:postgresql://{env['AWS_REDSHIFT_HOST']}:{env['AWS_REDSHIFT_PORT']}/{env['AWS_REDSHIFT_DBNAME']}") \
    .option("dbtable", f"{env['AWS_REDSHIFT_SCHEMA']}.new_releases_aruy_spotify") \
    .option("user", env['AWS_REDSHIFT_USER']) \
    .option("password", env['AWS_REDSHIFT_PASSWORD']) \
    .option("driver", "org.postgresql.Driver") \
    .mode("overwrite") \
    .save()

# %%
# chequeo con una consulta si los datos estan en la tabla creada en redshift
query = f"select * from {env['AWS_REDSHIFT_SCHEMA']}.new_releases_aruy_spotify"
data_redshift = spark.read \
    .format("jdbc") \
    .option("url", f"jdbc:postgresql://{env['AWS_REDSHIFT_HOST']}:{env['AWS_REDSHIFT_PORT']}/{env['AWS_REDSHIFT_DBNAME']}") \
    .option("dbtable", f"({query}) as tmp_table") \
    .option("user", env['AWS_REDSHIFT_USER']) \
    .option("password", env['AWS_REDSHIFT_PASSWORD']) \
    .option("driver", "org.postgresql.Driver") \
    .load()

# %%
data_redshift.printSchema()
data_redshift.show()
# Out:
# root
#  |-- artista: string (nullable = true)
#  |-- album: string (nullable = true)
#  |-- track: string (nullable = true)
#  |-- fecha_release: date (nullable = true)
#  |-- cant_reprod_track: integer (nullable = true)
#
# +----------------+--------------------+--------------------+-------------+-----------------+
# |         artista|               album|               track|fecha_release|cant_reprod_track|
# +----------------+--------------------+--------------------+-------------+-----------------+
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               84|
# |     Connie Isla|          Isla Mater|                 Gps|   2023-04-13|               46|
# |     Connie Isla|          Isla Mater|              No Ves|   2023-04-13|               38|
# |     Delfina Dib|     Directo al Cora|             ME OYES|   2023-04-14|               90|
# |       Mel Muñiz|La Santa Patrona ...|     Toda esa bronca|   2023-03-14|               36|
# |      Ñengo Flow|       Gato de Noche|       Gato de Noche|   2022-12-22|              176|
# |    Foo Fighters|     But Here We Are|           Beyond Me|   2023-06-02|              134|
# |           Bhavi|           ABDUCCION|            AEROBICO|   2023-04-10|               92|
# |              U2|  Songs Of Surrender|Out Of Control - ...|   2023-03-17|              102|
# |              U2|  Songs Of Surrender|Invisible - Songs...|   2023-03-17|              112|
# |     Miley Cyrus|Endless Summer Va...|              Island|   2023-03-10|              146|
# |   un muerto mas|  Verano en Invierno|     La Isla del Sol|   2022-12-16|               78|
# |            Lali|                LALI|                  KO|   2023-04-13|              118|
# |     Delfina Dib|     Directo al Cora|                 A.K|   2023-04-14|               56|
# |            TINI|              Cupido|             Fantasi|   2023-02-16|              132|
# |           Cazzu|Nena Trampa (Delu...|Los Hombres No Ll...|   2023-04-13|               86|
# |Usted Señalemelo|            Tripolar|           La Verdad|   2023-05-29|               92|
# |  Eladio Carrion|          3MEN2 KBRN|¿Qué Carajos Quie...|   2023-03-17|              148|
# |            TINI|              Cupido|             Te Pido|   2023-02-16|              140|
# | Andrés Calamaro|Razzmatazz (En di...|Me envenenaste - ...|   2023-06-02|               88|
# +----------------+--------------------+--------------------+-------------+-----------------+
# only showing top 20 rows

# %%
connection.close()
